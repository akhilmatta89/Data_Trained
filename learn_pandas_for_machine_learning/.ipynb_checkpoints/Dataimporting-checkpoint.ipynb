# %%
import pandas as pd

# %% [markdown]
# # Load .csv file

# %%
empls = pd.read_csv("empl.csv")

# %%
empls.head(2)
# Out:
#    SNo Name   Age     City Country   Salary
# 0    1  Tom  28.0  Toronto  Canada  20000.0
# 1    2  Lee  31.0  Edmonto  Canada   3900.0

# %%
empls.tail(2)
# Out:
#     SNo   Name   Age     City Country   Salary
# 20   22   Grig  26.0  Finland  Europe  33451.0
# 21   23  Kiara  27.0   London  Europe      NaN

# %%
#random data from dataset
empls.sample(n=10)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 20   22    Grig  26.0    Finland   Europe  33451.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 15   17    hari   NaN    newyork  America  67666.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 4     5   kamal  30.0        NaN  America      NaN
# 3     4    Anik  26.0   HongKong     Asia  66672.0

# %%
type(empls)
# Out:
# pandas.core.frame.DataFrame

# %%
#to find shape
empls.shape
# Out:
# (22, 6)

# %% [markdown]
# # Exporting Data

# %%
empls.to_csv('dummpy_empl.csv')

# %% [markdown]
# # Reading files

# %%
excel_file = pd.read_excel('employee.xlsx',sheet_name = 'uk-500')
excel_file
# Out:
#      first_name   last_name                    company_name  \
# 0       Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1          Evan   Zigomalas              Cap Gemini America
# 2        France     Andrade             Elliott, John W Esq
# 3       Ulysses   Mcwalters                  Mcmahan, Ben L
# 4        Tyisha      Veness                  Champagne Room
# ...         ...         ...                             ...
# 1995      Avery        Veit      Plaza Gourmet Delicatessen
# 1996       Reid     Euresti            Fitzgerald, Edward J
# 1997  Charlette    Brenning              Furey & Associates
# 1998  Celestina       Keeny        Bfg Federal Credit Union
# 1999         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                  address                            city           county  \
# 0           14 Taylor St               St. Stephens Ward             Kent
# 1            5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
excel_file = pd.read_excel('employee.xlsx',sheet_name = 'Sheet1')
excel_file
# Out:
# Empty DataFrame
# Columns: [This is created just for testing]
# Index: []
